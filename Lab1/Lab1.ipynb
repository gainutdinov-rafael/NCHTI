# %% [markdown]
# #Лабораторнаяработа №1
#
# ##Задание:
# ![photo_5269376684497424448_y.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##Выполнение задания:

# %%
print("Привет! Hello!")
name = input("What your name? \n")
firstname =""
while len(firstname.strip())<1:
  firstname = input("What your firstname? \n")
print(f"Nice to meet you, {name} {firstname}!")
# Out:
# Привет! Hello!
# What your name?
# Raf
# What your firstname?
# Gainutdinov
# Nice to meet you, Raf Gainutdinov!
